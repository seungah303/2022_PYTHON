# %% [markdown]
# <a href="https://colab.research.google.com/github/seungah303/2022_PYTHON/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC_3%EC%B0%A8_%EB%94%A5%EB%9F%AC%EB%8B%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #2차원 배열

# %%
mylist=[[10,20,30], [40, 50, 60]]

# %% [markdown]
# 1행의 1열

# %%
print(mylist[1][1])
# Out:
# 50

# %% [markdown]
# #버전 확인

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.21.6

# %% [markdown]
# # 맷플롯립으로 그래프 그리기

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4,5], [1,4,9,16,25])
plt.show( )

# %% [markdown]
# #산점도 그리기

# %%
plt.scatter([1, 2, 3, 4, 5], [1, 4, 9, 16, 25])
plt.show()

# %% [markdown]
# #넘파이 배열로 산점도 그리기

# %%
x=np.random.randn(1000)
y=np.random.randn(1000)
plt.scatter(y,x)
plt.show( )
